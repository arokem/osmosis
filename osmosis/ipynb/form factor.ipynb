# %%
def modulator(x,n):
    """
    A sin modulated by a power
    """
    return ((((np.sin(x) + 1)/2)**n))

# %%
x = np.linspace(0.1,np.pi*4, 1000)

# %%
fig,ax = plt.subplots(1)
ax.plot(modulator(y,0.5),label="n=0.5")
ax.plot(modulator(y,1), label="n=1")
ax.plot(modulator(y,2), label="n=2")
ax.plot(modulator(y,4), label="n=4")
fig.set_size_inches([8,6])
plt.legend()
