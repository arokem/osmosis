# %%
import osimport nibabel as niimport osmosis as ozimport osmosis.model as ozmimport osmosis.viz as vizimport osmosis.volume as ozvimport osmosis.utils as ozuimport osmosis.tensor as ozt reload(ozt)reload(ozm)reload(ozu)data_path = os.path.split(oz.__file__)[0] + '/data/'dwi1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz'dwi2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz'bvecs1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs'bvecs2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs'bvals1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals'bvals2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals'# If you want to choose some collection of voxels and analyze there: mask_array = np.zeros((81, 106, 76))mask_array[40:42,40:42,40:42] = 1# These are based on the calculations in GetADandRDAD, RD = (1.2855920166623125, 0.106324274669824)# Or, from theoretical considerations: # AD, RD, WD = (3.0, 0.0, 3.0)Model1 = ozm.CanonicalTensorModel(data_path + dwi1,                                 data_path + bvecs1,                                 data_path + bvals1,                                 mask=data_path + 'brainMask.nii.gz',                                 #mask=mask_array,                                 radial_diffusivity=RD,                                 axial_diffusivity=AD,                                  mode = 'signal_attenuation',                                 params_file = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilinSignalAttenuationModel.nii.gz'                                 )Model2 = ozm.CanonicalTensorModel(data_path + dwi1,                                 data_path + bvecs1,                                 data_path + bvals1,                                 mask=data_path + 'brainMask.nii.gz',                                 #mask=mask_array,                                 radial_diffusivity=RD,                                 axial_diffusivity=AD                                 )
# Out:
# Loading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvalsLoading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecsLoading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvalsLoading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs

# %%
fig,ax = plt.subplots(1)ten_param = Model1.model_params[...,1]to_hist = ten_param[~np.isnan(ten_param)]ax.hist(to_hist, histtype='step', label='SignalAttenuationModel', bins=1000)ten_param = Model2.model_params[...,1]to_hist = ten_param[~np.isnan(ten_param)]ax.hist(to_hist, histtype='step', label='CanonicalTensorModel', bins=4000)ax.set_xlim([0,1.2])plt.legend()fig,ax = plt.subplots(1)sphere_param = Model1.model_params[...,2]to_hist = sphere_param[~np.isnan(sphere_param)]ax.hist(to_hist, histtype='step', label='SignalAttenuationModel', bins=1000)sphere_param = Model2.model_params[...,2]to_hist = sphere_param[~np.isnan(sphere_param)]ax.hist(to_hist, histtype='step', label='CanonicalTensorModel', bins=4000)ax.set_xlim([0,1.2])plt.legend()fig,ax = plt.subplots(1)p_sum = Model1.model_params[...,1] + Model1.model_params[...,2]to_hist = p_sum[~np.isnan(p_sum)]ax.hist(to_hist, histtype='step', label='SignalAttenuationModel', bins=1000)p_sum = Model2.model_params[...,1] + Model2.model_params[...,2]to_hist = p_sum[~np.isnan(p_sum)]ax.hist(to_hist, histtype='step', label='CanonicalTensorModel', bins=4000)ax.set_xlim([0,1.2])plt.legend()
# Out:
# Loading params from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilinSignalAttenuationModel.nii.gzLoading params from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilinCanonicalTensorModel.nii.gz
