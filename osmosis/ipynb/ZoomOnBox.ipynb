# %%
import osmosis.viz 
import nibabel as ni

# %%
cd /Users/arokem/projects/osmosis/osmosis/data/
# Out:
# /Users/arokem/projects/osmosis/osmosis/data

# %%
d = ni.load('FP_t1_resampled_to_dwi.nii.gz').get_data()

# %%
fig, ax = plt.subplots(1)
ax.matshow(d[:,:,31],cmap=matplotlib.cm.bone)
ax.set_axis_off()
ax.plot([0,0],[0,0], linewidth=0.1, color='k')
fig.set_size_inches([8,8])

fig, ax = plt.subplots(1)
ax.matshow(d[:,:,31],cmap=matplotlib.cm.bone)
ax.plot([20,20],[20,30], linewidth=4, color='r')
ax.plot([30,30],[20,30], linewidth=4, color='r')
ax.plot([20,30],[20,20], linewidth=4, color='r')
ax.plot([20,30],[30,30], linewidth=4, color='r')
ax.set_axis_off()
fig.set_size_inches([8,8])

fig, ax = plt.subplots(1)
ax.matshow(d[20:30,20:30,31],cmap=matplotlib.cm.bone)
ax.set_axis_off()
