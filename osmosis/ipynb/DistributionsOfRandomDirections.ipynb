# %%
import osmosis.utils as ozuimport dipy.core.geometry as geo

# %%
dist = []fig, ax = subplots(1)for i in range(10000):    theta1 = np.pi * 2 * np.random.rand()     phi1 = np.pi * 2 * np.random.rand()    vec1 = geo.sphere2cart(1, theta1, phi1)    vec1_t = np.diag(-1 * np.eye(3) * vec1)    theta2 = np.pi * 2 * np.random.rand()     phi2 = np.pi * 2 * np.random.rand()    vec2 = geo.sphere2cart(1, theta2, phi2)    vec2_t = np.diag(-1 * np.eye(3) * vec2)    dist.append(np.min([np.rad2deg(ozu.vector_angle(vec1, vec2)),            np.rad2deg(ozu.vector_angle(vec1_t, vec2)),             np.rad2deg(ozu.vector_angle(vec1, vec2_t)),            np.rad2deg(ozu.vector_angle(vec1_t, vec2_t))]))    hist = ax.hist(dist,bins=50)ax.annotate(r'$\bar{x}=%2.2f$'%np.mean(dist), xy=(np.mean(dist), np.max(hist[0])), xytext=(np.mean(dist), np.max(hist[0]) + 50),            arrowprops=dict(facecolor='black', shrink=0.05))ax.set_ylim([0, np.max(hist[0]) + 100])ax.set_xlim([-10,100])ax.set_xlabel('Angle(degrees)')ax.set_ylabel('# instances')mean(dist)np.max(hist[0])
# Out:
# 303

# %%
dist = [] for i in range(10000):    xyz1 = np.random.rand(3) - 0.5    xyz2 = np.random.rand(3) - 0.5    dist.append(np.rad2deg(ozu.vector_angle(ozu.unit_vector(xyz1), ozu.unit_vector(xyz2))))    ax = hist(dist,bins=50)
