# %%
import os
import nibabel as ni

import osmosis as oz
import osmosis.model as ozm
import osmosis.viz as viz
import osmosis.utils as ozu
import osmosis.volume as ozv
import osmosis.io as oio
import osmosis.tensor as ozt
reload(ozt)
reload(oio)
reload(ozm)
reload(ozu)
reload(ozv)
reload(viz)
# Out:
# /home/arokem/usr/local/lib64/python2.7/site-packages/scikit_learn-0.12_git-py2.7-linux-x86_64.egg/scikits/__init__.py:1: UserWarning: Module dateutil was already imported from /home/arokem/usr/local/lib64/python2.7/site-packages/dateutil/__init__.pyc, but /usr/lib/python2.7/site-packages is being added to sys.path
#   __import__('pkg_resources').declare_namespace(__name__)
# <module 'osmosis.viz' from '/home/arokem/usr/lib/python2.7/site-packages/osmosis/viz.pyc'>

# %%
data_path = os.path.split(oz.__file__)[0] + '/data/'

dwi_4k_1 = '0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.nii.gz'
dwi_4k_2 = '0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.nii.gz'

bvecs_4k_1 = '0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs'
bvecs_4k_2 = '0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs'

bvals_4k_1 = '0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals'
bvals_4k_2 = '0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals'


TM_4k_1 = ozm.TensorModel(data_path + dwi_4k_1, 
                          data_path + bvecs_4k_1, 
                          data_path + bvals_4k_1, 
                          mask=data_path + 'brainMask.nii.gz')

TM_4k_2 = ozm.TensorModel(data_path + dwi_4k_2, 
                          data_path + bvecs_4k_2, 
                          data_path + bvals_4k_2,
                          mask=data_path + 'brainMask.nii.gz')


dwi_2k_1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz'
dwi_2k_2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz'

bvecs_2k_1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs'
bvecs_2k_2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs'

bvals_2k_1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals'
bvals_2k_2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals'


TM_2k_1 = ozm.TensorModel(data_path + dwi_2k_1, 
                          data_path + bvecs_2k_1, 
                          data_path + bvals_2k_1, 
                          mask=data_path + 'brainMask.nii.gz')


TM_2k_2 = ozm.TensorModel(data_path + dwi_2k_2, 
                          data_path + bvecs_2k_2, 
                          data_path + bvals_2k_2,
                          mask=data_path + 'brainMask.nii.gz')

dwi_1k_1 = '0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.nii.gz'
dwi_1k_2 = '0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.nii.gz'

bvecs_1k_1 = '0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs'
bvecs_1k_2 = '0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs'

bvals_1k_1 = '0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals'
bvals_1k_2 = '0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals'


TM_1k_1 = ozm.TensorModel(data_path + dwi_1k_1, 
                          data_path + bvecs_1k_1, 
                          data_path + bvals_1k_1, 
                          mask=data_path + 'brainMask.nii.gz')


TM_1k_2 = ozm.TensorModel(data_path + dwi_1k_2, 
                          data_path + bvecs_1k_2, 
                          data_path + bvals_1k_2,
                          mask=data_path + 'brainMask.nii.gz')
# Out:
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals

# %%
# We pick a voxel that is in Corpus Callosum: 
vox_idx = (40,75,33)

# %%
# %gui wx
reload(viz)
# Interpolate the signal from the measurement b-vectors using radial basis functions and display in 3D:
fig = viz.plot_signal_interp(TM_1k_1.relative_signal[vox_idx], TM_1k_1.bvecs[:,TM_1k_1.b_idx], cmap='hot', vmin=0, vmax=1)
fig = viz.plot_signal_interp(TM_2k_1.relative_signal[vox_idx], TM_2k_1.bvecs[:,TM_2k_1.b_idx], cmap='hot', vmin=0, vmax=1, figure=fig, offset=-2)
fig = viz.plot_signal_interp(TM_4k_1.relative_signal[vox_idx], TM_4k_1.bvecs[:,TM_4k_1.b_idx], cmap='hot', colorbar=True, vmin=0, vmax=1, figure=fig, offset=-4, file_name='/home/arokem/Dropbox/Figure1_1.pdf')

# %%
# We calculate and display ADC and the relative signal as 2D projections: 
fig_adc_1k = viz.sig_on_projection(TM_1k_1.bvecs[:,TM_1k_1.b_idx], TM_1k_1.adc[vox_idx],vmin=0, vmax=2.5)[1]
fig_adc_2k = viz.sig_on_projection(TM_2k_1.bvecs[:,TM_2k_1.b_idx], TM_2k_1.adc[vox_idx],vmin=0, vmax=2.5)[1]
fig_adc_4k = viz.sig_on_projection(TM_4k_1.bvecs[:,TM_4k_1.b_idx], TM_4k_1.adc[vox_idx],vmin=0, vmax=2.5)[1]

fig_adc_1k.savefig('/home/arokem/projects/osmosis/doc/figures/adc_1k.svg')
fig_adc_2k.savefig('/home/arokem/projects/osmosis/doc/figures/adc_2k.svg')
fig_adc_4k.savefig('/home/arokem/projects/osmosis/doc/figures/adc_4k.svg')

fig_sig_1k = viz.sig_on_projection(TM_1k_1.bvecs[:,TM_1k_1.b_idx], TM_1k_1.relative_signal[vox_idx], vmin=0, vmax=1)[1]
fig_sig_2k = viz.sig_on_projection(TM_2k_1.bvecs[:,TM_2k_1.b_idx], TM_2k_1.relative_signal[vox_idx], vmin=0, vmax=1)[1]
fig_sig_4k = viz.sig_on_projection(TM_4k_1.bvecs[:,TM_4k_1.b_idx], TM_4k_1.relative_signal[vox_idx], vmin=0, vmax=1)[1]

fig_sig_1k.savefig('/home/arokem/projects/osmosis/doc/figures/relative_signal_1k.svg')
fig_sig_2k.savefig('/home/arokem/projects/osmosis/doc/figures/relative_signal_2k.svg')
fig_sig_4k.savefig('/home/arokem/projects/osmosis/doc/figures/relative_signal_4k.svg')

# %%
# %gui wx
reload(viz)
ten_1k = ozt.tensor_from_eigs(TM_1k_1.model_params[vox_idx][3:].reshape(3,3), 
                           TM_1k_1.model_params[vox_idx][:3], 
                           TM_1k_1.bvecs[:, TM_1k_1.b_idx], TM_1k_1.bvals[TM_1k_1.b_idx])

fig = viz.plot_tensor_3d(ten_1k, mode='ADC', cmap='hot', colorbar=True, vmin=0, vmax=2.5)
ten_2k = ozt.tensor_from_eigs(TM_2k_1.model_params[vox_idx][3:].reshape(3,3), 
                           TM_2k_1.model_params[vox_idx][:3], 
                           TM_2k_1.bvecs[:, TM_2k_1.b_idx], TM_2k_1.bvals[TM_2k_1.b_idx])

fig = viz.plot_tensor_3d(ten_2k, mode='ADC', cmap='hot', vmin=0, vmax=2.5, figure=fig, offset=-2.5)


ten_4k = ozt.tensor_from_eigs(TM_4k_1.model_params[vox_idx][3:].reshape(3,3), 
                           TM_4k_1.model_params[vox_idx][:3], 
                           TM_4k_1.bvecs[:, TM_4k_1.b_idx], TM_4k_1.bvals[TM_4k_1.b_idx])

fig = viz.plot_tensor_3d(ten_4k, mode='ADC', cmap='hot', vmin=0, vmax=2.5, figure=fig, offset=-5, file_name='/home/arokem/Dropbox/Figure1_2.pdf')
# Out:
# Loading TensorModel params from: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilinTensorModel.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs
# Loading TensorModel params from: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilinTensorModel.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs
# Loading TensorModel params from: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilinTensorModel.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs

# %%
reload(viz)
# %gui wx
ten_1k = ozt.tensor_from_eigs(TM_1k_1.model_params[vox_idx][3:].reshape(3,3), 
                           TM_1k_1.model_params[vox_idx][:3], 
                           TM_1k_1.bvecs[:, TM_1k_1.b_idx], TM_1k_1.bvals[TM_1k_1.b_idx])

fig = viz.plot_tensor_3d(ten_1k, mode='ellipse', cmap='Greens', colorbar=True)
ten_2k = ozt.tensor_from_eigs(TM_2k_1.model_params[vox_idx][3:].reshape(3,3), 
                           TM_2k_1.model_params[vox_idx][:3], 
                           TM_2k_1.bvecs[:, TM_2k_1.b_idx], TM_2k_1.bvals[TM_2k_1.b_idx])

fig = viz.plot_tensor_3d(ten_2k, mode='ellipse', cmap='Greens',  offset=-2.5, figure=fig)


ten_4k = ozt.tensor_from_eigs(TM_4k_1.model_params[vox_idx][3:].reshape(3,3), 
                           TM_4k_1.model_params[vox_idx][:3], 
                           TM_4k_1.bvecs[:, TM_4k_1.b_idx], TM_4k_1.bvals[TM_4k_1.b_idx])

fig = viz.plot_tensor_3d(ten_4k, mode='ellipse', cmap='Greens', offset=-5, figure=fig, file_name='/home/arokem/Dropbox/Ellipse.pdf')
# Out:
# Loading TensorModel params from: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilinTensorModel.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs
# Loading TensorModel params from: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilinTensorModel.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs
# Loading TensorModel params from: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilinTensorModel.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs
# /home/arokem/usr/lib/python2.7/site-packages/osmosis/tensor.py:135: RuntimeWarning: invalid value encountered in sqrt
# ...

# %%
fig, axes = plt.subplots(1,3,squeeze=True)
axes[0].set_ylabel(r'$\frac{S}{S_0}$')
for ax, models in zip(axes,([TM_1k_1,TM_1k_2],[TM_2k_1, TM_2k_2],[TM_4k_1, TM_4k_2])):
    ax.scatter(models[0].relative_signal[vox_idx], models[1].relative_signal[vox_idx])
    ax.grid()
    ax.set_xlim([0,1])
    ax.set_ylim([0,1])
    ax.set_aspect('equal')
    ax.set_xlabel(r'$\frac{S}{S_0}$')
    
fig.set_size_inches([10,10])
fig.savefig('/home/arokem/Dropbox/Measured_measured')

# %%
fig, axes = plt.subplots(1,3,squeeze=True)
axes[0].set_ylabel(r'Predicted $\frac{S}{S_0}$')
for ax, models in zip(axes,([TM_1k_1,TM_1k_2],[TM_2k_1, TM_2k_2],[TM_4k_1, TM_4k_2])):
    ax.scatter(models[0].relative_signal[vox_idx], models[1].fit[vox_idx]/models[1].S0[vox_idx])
    ax.grid()
    ax.set_xlim([0,1])
    ax.set_ylim([0,1])
    ax.set_aspect('equal')
    ax.set_xlabel(r'Measured $\frac{S}{S_0}$')
    
fig.set_size_inches([10,10])
fig.savefig('/home/arokem/Dropbox/Figure1_3')
