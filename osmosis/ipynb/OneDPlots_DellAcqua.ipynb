# %%
theta = np.linspace(1,2*np.pi,100)
para = [1.5, 1.7, 2]
ortho = [0.5, 0.3]
for d_para in para:
    for d_ortho in ortho:
        D = d_para * np.cos(theta)**2 + d_ortho * np.sin(theta)**2
        plot(D)
