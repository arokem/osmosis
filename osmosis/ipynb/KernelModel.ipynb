# %%
import os
import nibabel as ni

import osmosis as oz
import osmosis.model as ozm
import osmosis.viz as viz
import osmosis.utils as ozu
import osmosis.volume as ozv
import osmosis.io as oio
reload(oio)
reload(ozm)
reload(ozu)
reload(ozv)
reload(viz)
# Out:
# <module 'osmosis.viz' from '/Users/arokem/usr/lib/python2.7/site-packages/osmosis/viz.pyc'>

# %%
data_path = os.path.split(oz.__file__)[0] + '/data/'

wm_mask = ni.load(data_path + 'FP_white_matter_resamp_to_dwi.nii.gz').get_data()

# If you want to choose some collection of voxels and analyze there: 
mask_array = np.zeros((81, 106, 76))

# mask_array[40:42,40:42,40:42] = 1
mask_array[np.isfinite(wm_mask)] = 1


dwi_4k_1 = '0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.nii.gz'
dwi_4k_2 = '0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.nii.gz'

bvecs_4k_1 = '0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs'
bvecs_4k_2 = '0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs'

bvals_4k_1 = '0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals'
bvals_4k_2 = '0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals'


TM_4k_1 = ozm.SparseKernelModel(data_path + dwi_4k_1, 
                          data_path + bvecs_4k_1, 
                          data_path + bvals_4k_1, 
                          mask=mask_array,
                          #sh_order=10,
                          params_file = data_path + dwi_4k_1.split('.')[0] + 'SparseKernelModel.nii.gz'
                         )


TM_4k_2 = ozm.SparseKernelModel(data_path + dwi_4k_2, 
                          data_path + bvecs_4k_2, 
                          data_path + bvals_4k_2,
                          mask=mask_array,
                          #sh_order=10,
                          params_file = data_path + dwi_4k_2.split('.')[0] + 'SparseKernelModel.nii.gz'
                         )


dwi_2k_1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz'
dwi_2k_2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz'

bvecs_2k_1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs'
bvecs_2k_2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs'

bvals_2k_1 = '0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals'
bvals_2k_2 = '0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals'

TM_2k_1 = ozm.SparseKernelModel(data_path + dwi_2k_1, 
                          data_path + bvecs_2k_1, 
                          data_path + bvals_2k_1, 
                          mask=mask_array,
                          #sh_order=10,
                          params_file = data_path + dwi_2k_1.split('.')[0] + 'SparseKernelModel.nii.gz'
                         )


TM_2k_2 = ozm.SparseKernelModel(data_path + dwi_2k_2, 
                          data_path + bvecs_2k_2, 
                          data_path + bvals_2k_2,
                          mask=mask_array,
                          #sh_order=10,
                          params_file = data_path + dwi_2k_2.split('.')[0] + 'SparseKernelModel.nii.gz'
                          )

dwi_1k_1 = '0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.nii.gz'
dwi_1k_2 = '0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.nii.gz'

bvecs_1k_1 = '0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs'
bvecs_1k_2 = '0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs'

bvals_1k_1 = '0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals'
bvals_1k_2 = '0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals'


TM_1k_1 = ozm.SparseKernelModel(data_path + dwi_1k_1, 
                         data_path + bvecs_1k_1, 
                          data_path + bvals_1k_1, 
                          mask=mask_array,
                          #sh_order=10,
                          params_file = data_path + dwi_1k_1.split('.')[0] + 'SparseKernelModel.nii.gz'
                         )


TM_1k_2 = ozm.SparseKernelModel(data_path + dwi_1k_2, 
                          data_path + bvecs_1k_2, 
                          data_path + bvals_1k_2,
                          mask=mask_array,
                          #sh_order=10,
                          params_file = data_path + dwi_1k_2.split('.')[0] + 'SparseKernelModel.nii.gz'
                         )
# Out:
# Loading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals
# Loading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals
# Loading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals
# Loading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals
# Loading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals
# Loading from file: /Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals

# %%
TM_2k_2.params_file
# Out:
# '/Users/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilinSparseKernelModel.nii.gz'

# %%
relative_rmse_1k = ozm.relative_rmse(TM_1k_1, TM_1k_2)
relative_rmse_2k = ozm.relative_rmse(TM_2k_1, TM_2k_2)
relative_rmse_4k = ozm.relative_rmse(TM_4k_1, TM_4k_2)
# Out:
# SparseKernelModel.fit [****************100%******************]  59551 of 59552 complete

# %%
oio.nii_from_volume(relative_rmse_1k, data_path + 'SparseKernelModel_sh_order10_relative_rmse_b1000.nii.gz', ni.load(data_path + dwi_1k_1).get_affine())
oio.nii_from_volume(relative_rmse_2k, data_path + 'SparseKernelModel_sh_order10_relative_rmse_b2000.nii.gz', ni.load(data_path + dwi_2k_1).get_affine())
oio.nii_from_volume(relative_rmse_4k, data_path + 'SparseKernelModel_sh_order10_relative_rmse_b4000.nii.gz', ni.load(data_path + dwi_4k_1).get_affine())

# %%
qtconsole

# %%
fig, ax = plt.subplots(1)

.hist(relative_rmse_1k[np.isfinite(relative_rmse_1k)], histtype='step', bins=1000, label='b=1000')
ax.hist(relative_rmse_2k[np.isfinite(relative_rmse_2k)], histtype='step', bins=4000, label='b=2000')
ax.hist(relative_rmse_4k[np.isfinite(relative_rmse_4k)], histtype='step', bins=2500, label='b=4000')

fig.set_size_inches([10,5])
ax.set_xlim([0,4])
plt.legend()

ax.set_ylabel('# voxels')
ax.set_xlabel('$RMSE_{relative}$')
ax.set_title('Kernel model')

# %%
vox_idx = (40,40,40)

# %%
viz.sig_on_projection(TM_2k_1.bvecs[:, TM_2k_1.b_idx], TM_2k_1.signal[vox_idx], tri=True)
viz.sig_on_projection(TM_2k_1.bvecs[:, TM_2k_1.b_idx], TM_2k_1.fit[vox_idx], tri=True)

fig, ax = plt.subplots(1)
ax.scatter(TM_2k_1.signal[vox_idx],
           TM_2k_1.fit[vox_idx])

# %%
viz.sig_on_projection(TM_2k_1.bvecs[:, TM_2k_1.b_idx], TM_2k_1.signal[vox_idx], tri=True)
viz.sig_on_projection(TM_4k_1.odf_verts[0].T, TM_4k_1.odf[vox_idx])
# Out:
# (<mpl_toolkits.basemap.Basemap at 0x110382c10>,
#  <matplotlib.figure.Figure at 0x11073c0d0>)

# %%
hist(TM_4k_1.fit_angle[np.isfinite(TM_4k_1.fit_angle)], histtype='step')
# Out:
# SparseKernelModel.odf [****************100%******************]  203992 of 203993 complete
# (array([ 1884,  3442, 80800,  6822,  5875,  5077,  3107,  5582,   895,   240]),
#  array([   8.00626179,   24.40500943,   40.80375707,   57.20250471,
#          73.60125236,   90.        ,  106.39874764,  122.79749529,
#         139.19624293,  155.59499057,  171.99373821]),
#  <a list of 1 Patch objects>)
