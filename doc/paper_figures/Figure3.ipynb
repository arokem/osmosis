# %%
import os
import tempfile

from IPython.display import Image, display
import nibabel as ni

import osmosis as oz
import osmosis.viz.maya as viz
import osmosis.utils as ozu
import osmosis.io as oio
import osmosis.model.dti as dti
import osmosis.model.analysis as oza
# Out:
# /home/arokem/usr/local/lib64/python2.7/site-packages/mayavi-4.0.0-py2.7-linux-x86_64.egg/mayavi/preferences/preference_manager.py:24: UserWarning: Module dateutil was already imported from /home/arokem/usr/local/lib64/python2.7/site-packages/dateutil/__init__.pyc, but /usr/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %%
data_1k_1, data_1k_2 = oio.get_dwi_data(1000)
data_2k_1, data_2k_2 = oio.get_dwi_data(2000)
data_4k_1, data_4k_2 = oio.get_dwi_data(4000)

# %%
wm_mask = np.zeros(ni.load(data_1k_1[0]).shape[:3])
wm_nifti = ni.load(oio.data_path + 'FP_WM_2iso_2k_MD_outliers_excluded.nii.gz').get_data()
wm_mask[np.where(wm_nifti==1)] = 1

# %%
TM_1k_1 = dti.TensorModel(*data_1k_1, mask=wm_mask, params_file='temp')
TM_1k_2 = dti.TensorModel(*data_1k_2, mask=wm_mask, params_file='temp')
TM_2k_1 = dti.TensorModel(*data_2k_1, mask=wm_mask, params_file='temp')
TM_2k_2 = dti.TensorModel(*data_2k_2, mask=wm_mask, params_file='temp')
TM_4k_1 = dti.TensorModel(*data_4k_1, mask=wm_mask, params_file='temp')
TM_4k_2 = dti.TensorModel(*data_4k_2, mask=wm_mask, params_file='temp')
# Out:
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvals

# %%
vol_anat = oio.get_t1(resample=ni.load(oio.data_path + 'FP_WM_2iso_2k_MD_outliers_excluded.nii.gz'))

# %%
rrmse_data = [oza.relative_rmse(TM_1k_1, TM_1k_2), oza.relative_rmse(TM_2k_1, TM_2k_2), oza.relative_rmse(TM_4k_1, TM_4k_2)]
# Out:
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.nii.gz
# Predicting signal from TensorModel
# Fitting TensorModel params using dipy
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0009_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs
# Predicting signal from TensorModel
# Fitting TensorModel params using dipy
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0011_01_DWI_2mm150dir_2x_b1000_aligned_trilin.bvecs
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.nii.gz
# Predicting signal from TensorModel
# Fitting TensorModel params using dipy
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs
# Predicting signal from TensorModel
# Fitting TensorModel params using dipy
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DTI_2mm_150dir_2x_b2000_aligned_trilin.bvecs
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.nii.gz
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.nii.gz
# Predicting signal from TensorModel
# Fitting TensorModel params using dipy
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0005_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs
# Predicting signal from TensorModel
# Fitting TensorModel params using dipy
# Loading from file: /home/arokem/usr/lib/python2.7/site-packages/osmosis/data/0007_01_DWI_2mm150dir_2x_b4000_aligned_trilin.bvecs

# %%
fn = []
for vol_rmse in rrmse_data:
    fn.append('%s.png'%tempfile.NamedTemporaryFile().name)
    viz.plot_cut_planes(vol_anat,
                        overlay=vol_rmse,
                        vmin=0.5,
                        vmax=1.5,
                        overlay_cmap="RdYlGn",
                        invert_cmap=True,
                        slice_coronal=40,
                        slice_saggital=15,
                        slice_axial=30,
                        view_azim=-40,
                        view_elev=60,
                        file_name=fn[-1])
# Out:
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x16903410>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0xe22ffb0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0xe2412f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0xe250650>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0xe259a10>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0xe263d10>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x9a468f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x9a50c50>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x11c6cf50>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x11c81290>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x11c8a590>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x11c91890>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x134adfb0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x134ba2f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x134cb5f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x134d08f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x134dcbf0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x13b94ef0>

# %%
for this_fn in fn:
    i = Image(filename=this_fn, width=1280, height=1024)
    display(i)

# %%
fn = []
for vol_rmse in rrmse_data:
    fn.append('%s.png'%tempfile.NamedTemporaryFile().name)
    viz.plot_cut_planes(vol_anat,
                        overlay=vol_rmse,
                        vmin=0.5,
                        vmax=1.5,
                        overlay_cmap="RdYlGn",
                        invert_cmap=True,
                        slice_coronal=40,
                        slice_saggital=15,
                        slice_axial=45,
                        view_azim=40,
                        view_elev=60,
                        file_name=fn[-1])
# Out:
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x13bb85f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x13bc38f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x19a33bf0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x19a3cef0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x19a541d0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x19a5b530>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1aee7c50>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1aef1f50>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1af07290>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1af14590>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1bff7890>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1c005b90>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1c02e2f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1d0c65f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1d0cf8f0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1d0d9bf0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1d0e5ef0>
# Cannot set extents for <mayavi.modules.image_plane_widget.ImagePlaneWidget object at 0x1d0fc1d0>

# %%
for this_fn in fn:
    i = Image(filename=this_fn, width=1280, height=1024)
    display(i)
